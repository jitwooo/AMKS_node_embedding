# %%
from experiment_util.parms_tune import Params, BestScoreParamRecorder, search_grid_generator
from model.synthetic_graph import fan, house, star, build_circle_structure_split
import numpy as np
from model.AMKS.amks import MultiHopAMKS
from running.log import get_logger
import datetime
from tqdm import tqdm
from sklearn.cluster import KMeans
import sklearn.metrics as sk_metrics
from sklearn import utils as sk_utils
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import cross_val_score

# %%
class CurParams(Params):
    def __init__(self) -> None:
        super().__init__()
        self._hop = None
        self._sigma = None
        self._step = None

    def update(self, other):
        self._hop = other._hop
        self._sigma = other._sigma
        self._step = other._step

    def to_str(self):
        return f"step:{self._step}_sigma:{self._sigma}_hop:{self._hop}"

# %%
g, roles = build_circle_structure_split([[fan, 6], [star, 6], [house]], 2, 16)
label = np.array(roles)
compute_model = MultiHopAMKS()

# %%
sigma_range = np.linspace(0, 4, 20)[1:]
hop_range = list(range(0, 6))
step_range = list(range(3, 30, 3))

time = 50
compute_model.set_g(g)
compute_model.set_time(time)

node_index = sorted(g.nodes)

# %%
hom_recorder = BestScoreParamRecorder(CurParams(), -1, "hom")
comp_recorder = BestScoreParamRecorder(CurParams(), -1, "comp")
sil_recorder = BestScoreParamRecorder(CurParams(), -1, "sil")
acc_recorder = BestScoreParamRecorder(CurParams(), -1, "acc")
macro_fi_recorder = BestScoreParamRecorder(CurParams(), -1, "macro_f1")

# %%
logger = get_logger("amks synthetic")
logger.info("find best params of synthetic graph waveRing")
logger.info("time = " + str(time))
start_time = datetime.datetime.now()
params = CurParams()

# %%
def unsupervised_evaluate(embedding_vec: np.ndarray, labels: np.ndarray):
    """计算3个衡量的指标"""
    colors = labels
    nb_clust = len(np.unique(colors))
    trans_data = embedding_vec
    km = KMeans(n_clusters=nb_clust)
    km.fit(trans_data)
    labels_pred = km.labels_
    hom = sk_metrics.homogeneity_score(colors, labels_pred)
    comp = sk_metrics.completeness_score(colors, labels_pred)
    sil = sk_metrics.silhouette_score(trans_data, labels_pred, metric='euclidean')

    return hom, comp, sil

# %%
def supervised_evaluate(embedding_vec: np.ndarray, labels: np.ndarray):
    """4最近邻和交叉验证，评估模型的有监督嵌入能力"""
    data, labels = sk_utils.shuffle(embedding_vec, labels)
    knn = KNeighborsClassifier(n_neighbors=4)
    acc_score = cross_val_score(knn, data, y=labels, cv=5, scoring='accuracy')
    macro_f1 = cross_val_score(knn, data, y=labels, cv=5, scoring='f1_macro')
    return np.mean(acc_score), np.mean(macro_f1)

# %%
for sigma, hop, step in tqdm(list(search_grid_generator(sigma_range, hop_range, step_range))):
    compute_model.set_maxhop(hop)
    compute_model.set_sigma(sigma)
    compute_model.set_step(step)

    compute_model.compute_emb_vec()
    embedding_vec = compute_model.get_embedding_vec(node_index)

    hom, comp, sil = unsupervised_evaluate(embedding_vec, label)

    acc, macro_f1 = supervised_evaluate(embedding_vec, label)

    params._hop = hop
    params._sigma = sigma
    params._step = step

    hom_recorder.update_params(params, hom, logger)
    comp_recorder.update_params(params, comp, logger)
    sil_recorder.update_params(params, sil, logger)
    acc_recorder.update_params(params, acc, logger)
    macro_fi_recorder.update_params(params, macro_f1, logger)

time_spent = datetime.datetime.now() - start_time
min_ = time_spent.seconds // 60
sec = time_spent.seconds % 60
logger.info("time spent: " + str(min_) + " min" + str(sec) + " s")
# Out:
#   0%|          | 1/1026 [00:00<13:12,  1.29it/s]/tmp/ipykernel_420/3009232229.py:7: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   km.fit(trans_data)
#   0%|          | 5/1026 [00:04<15:32,  1.09it/s]/tmp/ipykernel_420/3009232229.py:7: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   km.fit(trans_data)
#   1%|          | 11/1026 [00:09<13:07,  1.29it/s]/tmp/ipykernel_420/3009232229.py:7: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   km.fit(trans_data)
#   1%|▏         | 14/1026 [00:11<13:20,  1.26it/s]/tmp/ipykernel_420/3009232229.py:7: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   km.fit(trans_data)
#   2%|▏         | 17/1026 [00:14<16:36,  1.01it/s]/tmp/ipykernel_420/3009232229.py:7: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   km.fit(trans_data)
#   2%|▏         | 20/1026 [00:16<13:59,  1.20it/s]/tmp/ipykernel_420/3009232229.py:7: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   km.fit(trans_data)
#   2%|▏         | 21/1026 [00:17<13:24,  1.25it/s]/tmp/ipykernel_420/3009232229.py:7: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   km.fit(trans_data)
#   2%|▏         | 24/1026 [00:19<12:49,  1.30it/s]/tmp/ipykernel_420/3009232229.py:7: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   km.fit(trans_data)
#   2%|▏         | 25/1026 [00:20<13:02,  1.28it/s]/tmp/ipykernel_420/3009232229.py:7: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   km.fit(trans_data)
#   3%|▎         | 29/1026 [00:24<13:27,  1.23it/s]/tmp/ipykernel_420/3009232229.py:7: ConvergenceWarning: Number of distinct clusters (18) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   km.fit(trans_data)
#   3%|▎         | 32/1026 [00:26<12:14,  1.35it/s]/tmp/ipykernel_420/3009232229.py:7: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   km.fit(trans_data)
#   3%|▎         | 34/1026 [00:27<12:00,  1.38it/s]/tmp/ipykernel_420/3009232229.py:7: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   km.fit(trans_data)
#   3%|▎         | 35/1026 [00:28<12:14,  1.35it/s]/tmp/ipykernel_420/3009232229.py:7: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   km.fit(trans_data)
#   4%|▎         | 37/1026 [00:30<12:10,  1.35it/s]/tmp/ipykernel_420/3009232229.py:7: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   km.fit(trans_data)
#   4%|▍         | 43/1026 [00:34<11:35,  1.41it/s]/tmp/ipykernel_420/3009232229.py:7: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   km.fit(trans_data)
#   5%|▍         | 47/1026 [00:37<11:34,  1.41it/s]/tmp/ipykernel_420/3009232229.py:7: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   km.fit(trans_data)
#   5%|▍         | 48/1026 [00:37<11:27,  1.42it/s]/tmp/ipykernel_420/3009232229.py:7: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   km.fit(trans_data)
#   5%|▍         | 51/1026 [00:40<11:28,  1.42it/s]/tmp/ipykernel_420/3009232229.py:7: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   km.fit(trans_data)
#   5%|▌         | 55/1026 [00:42<11:03,  1.46it/s]/tmp/ipykernel_420/3009232229.py:7: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   km.fit(trans_data)
#   5%|▌         | 56/1026 [00:43<11:09,  1.45it/s]/tmp/ipykernel_420/3009232229.py:7: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   km.fit(trans_data)
#   6%|▌         | 60/1026 [00:46<11:20,  1.42it/s]/tmp/ipykernel_420/3009232229.py:7: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   km.fit(trans_data)
#   6%|▌         | 62/1026 [00:47<11:37,  1.38it/s]/tmp/ipykernel_420/3009232229.py:7: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   km.fit(trans_data)
#   6%|▋         | 66/1026 [00:50<11:18,  1.42it/s]/tmp/ipykernel_420/3009232229.py:7: ConvergenceWarning: Number of distinct clusters (18) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   km.fit(trans_data)
#   7%|▋         | 69/1026 [00:52<11:29,  1.39it/s]/tmp/ipykernel_420/3009232229.py:7: ConvergenceWarning: Number of distinct clusters (18) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   km.fit(trans_data)
#   7%|▋         | 71/1026 [00:54<11:55,  1.33it/s]/tmp/ipykernel_420/3009232229.py:7: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   km.fit(trans_data)
#   7%|▋         | 75/1026 [00:57<11:08,  1.42it/s]/tmp/ipykernel_420/3009232229.py:7: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   km.fit(trans_data)
#   7%|▋         | 76/1026 [00:57<11:00,  1.44it/s]/tmp/ipykernel_420/3009232229.py:7: ConvergenceWarning: Number of distinct clusters (18) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   km.fit(trans_data)
#   8%|▊         | 77/1026 [00:58<11:12,  1.41it/s]/tmp/ipykernel_420/3009232229.py:7: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   km.fit(trans_data)
#   8%|▊         | 78/1026 [00:59<11:29,  1.37it/s]/tmp/ipykernel_420/3009232229.py:7: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   km.fit(trans_data)
#   8%|▊         | 80/1026 [01:00<11:33,  1.36it/s]/tmp/ipykernel_420/3009232229.py:7: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   km.fit(trans_data)
#   8%|▊         | 86/1026 [01:05<11:20,  1.38it/s]/tmp/ipykernel_420/3009232229.py:7: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   km.fit(trans_data)
#   9%|▊         | 89/1026 [01:07<11:19,  1.38it/s]/tmp/ipykernel_420/3009232229.py:7: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   km.fit(trans_data)
#   9%|▉         | 94/1026 [01:10<10:42,  1.45it/s]/tmp/ipykernel_420/3009232229.py:7: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   km.fit(trans_data)
#  10%|▉         | 99/1026 [01:14<11:08,  1.39it/s]/tmp/ipykernel_420/3009232229.py:7: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   km.fit(trans_data)
#  10%|▉         | 101/1026 [01:15<10:56,  1.41it/s]/tmp/ipykernel_420/3009232229.py:7: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   km.fit(trans_data)
#  10%|█         | 105/1026 [01:18<11:04,  1.39it/s]/tmp/ipykernel_420/3009232229.py:7: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   km.fit(trans_data)
#  10%|█         | 107/1026 [01:20<11:07,  1.38it/s]/tmp/ipykernel_420/3009232229.py:7: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   km.fit(trans_data)
#  11%|█         | 111/1026 [01:22<10:44,  1.42it/s]/tmp/ipykernel_420/3009232229.py:7: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   km.fit(trans_data)
#  11%|█         | 112/1026 [01:23<11:02,  1.38it/s]/tmp/ipykernel_420/3009232229.py:7: ConvergenceWarning: Number of distinct clusters (18) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   km.fit(trans_data)
#  11%|█         | 113/1026 [01:24<11:02,  1.38it/s]/tmp/ipykernel_420/3009232229.py:7: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   km.fit(trans_data)
#  11%|█         | 115/1026 [01:25<11:09,  1.36it/s]/tmp/ipykernel_420/3009232229.py:7: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   km.fit(trans_data)
#  12%|█▏        | 119/1026 [01:28<10:49,  1.40it/s]/tmp/ipykernel_420/3009232229.py:7: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   km.fit(trans_data)
#  12%|█▏        | 121/1026 [01:30<10:37,  1.42it/s]/tmp/ipykernel_420/3009232229.py:7: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   km.fit(trans_data)
#  12%|█▏        | 122/1026 [01:30<10:37,  1.42it/s]/tmp/ipykernel_420/3009232229.py:7: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   km.fit(trans_data)
#  12%|█▏        | 127/1026 [01:34<10:38,  1.41it/s]/tmp/ipykernel_420/3009232229.py:7: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   km.fit(trans_data)
#  13%|█▎        | 131/1026 [01:37<10:21,  1.44it/s]/tmp/ipykernel_420/3009232229.py:7: ConvergenceWarning: Number of distinct clusters (18) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   km.fit(trans_data)
#  13%|█▎        | 132/1026 [01:37<10:26,  1.43it/s]/tmp/ipykernel_420/3009232229.py:7: ConvergenceWarning: Number of distinct clusters (18) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   km.fit(trans_data)
#  13%|█▎        | 138/1026 [01:41<09:46,  1.52it/s]/tmp/ipykernel_420/3009232229.py:7: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   km.fit(trans_data)
#  14%|█▎        | 139/1026 [01:42<10:06,  1.46it/s]/tmp/ipykernel_420/3009232229.py:7: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   km.fit(trans_data)
#  14%|█▍        | 143/1026 [01:45<10:33,  1.39it/s]/tmp/ipykernel_420/3009232229.py:7: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   km.fit(trans_data)
#  14%|█▍        | 147/1026 [01:48<10:30,  1.39it/s]/tmp/ipykernel_420/3009232229.py:7: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   km.fit(trans_data)
#  14%|█▍        | 148/1026 [01:49<10:21,  1.41it/s]/tmp/ipykernel_420/3009232229.py:7: ConvergenceWarning: Number of distinct clusters (18) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   km.fit(trans_data)
#  15%|█▍        | 149/1026 [01:49<10:15,  1.42it/s]/tmp/ipykernel_420/3009232229.py:7: ConvergenceWarning: Number of distinct clusters (18) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   km.fit(trans_data)
#  15%|█▍        | 150/1026 [01:50<10:05,  1.45it/s]/tmp/ipykernel_420/3009232229.py:7: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   km.fit(trans_data)
#  15%|█▍        | 151/1026 [01:51<10:21,  1.41it/s]/tmp/ipykernel_420/3009232229.py:7: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   km.fit(trans_data)
#  15%|█▌        | 158/1026 [01:55<09:44,  1.49it/s]/tmp/ipykernel_420/3009232229.py:7: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   km.fit(trans_data)
#  16%|█▌        | 161/1026 [01:58<10:06,  1.43it/s]/tmp/ipykernel_420/3009232229.py:7: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   km.fit(trans_data)
#  16%|█▌        | 166/1026 [02:01<09:54,  1.45it/s]/tmp/ipykernel_420/3009232229.py:7: ConvergenceWarning: Number of distinct clusters (18) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   km.fit(trans_data)
#  16%|█▋        | 167/1026 [02:02<09:48,  1.46it/s]/tmp/ipykernel_420/3009232229.py:7: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   km.fit(trans_data)
#  16%|█▋        | 169/1026 [02:03<10:16,  1.39it/s]/tmp/ipykernel_420/3009232229.py:7: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   km.fit(trans_data)
#  17%|█▋        | 173/1026 [02:06<10:00,  1.42it/s]/tmp/ipykernel_420/3009232229.py:7: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   km.fit(trans_data)
#  18%|█▊        | 188/1026 [02:20<14:18,  1.02s/it]/tmp/ipykernel_420/3009232229.py:7: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   km.fit(trans_data)
#  19%|█▊        | 192/1026 [02:23<10:51,  1.28it/s]/tmp/ipykernel_420/3009232229.py:7: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   km.fit(trans_data)
#  20%|██        | 208/1026 [02:36<11:02,  1.23it/s]/tmp/ipykernel_420/3009232229.py:7: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   km.fit(trans_data)
#  20%|██        | 209/1026 [02:36<10:22,  1.31it/s]/tmp/ipykernel_420/3009232229.py:7: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   km.fit(trans_data)
#  21%|██        | 216/1026 [02:41<09:46,  1.38it/s]/tmp/ipykernel_420/3009232229.py:7: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   km.fit(trans_data)
#  21%|██        | 218/1026 [02:43<09:39,  1.39it/s]/tmp/ipykernel_420/3009232229.py:7: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   km.fit(trans_data)
#  22%|██▏       | 223/1026 [02:46<09:49,  1.36it/s]/tmp/ipykernel_420/3009232229.py:7: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   km.fit(trans_data)
#  22%|██▏       | 230/1026 [02:51<09:04,  1.46it/s]/tmp/ipykernel_420/3009232229.py:7: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   km.fit(trans_data)
#  23%|██▎       | 239/1026 [02:57<09:16,  1.42it/s]/tmp/ipykernel_420/3009232229.py:7: ConvergenceWarning: Number of distinct clusters (18) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   km.fit(trans_data)
#  23%|██▎       | 240/1026 [02:58<09:25,  1.39it/s]/tmp/ipykernel_420/3009232229.py:7: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   km.fit(trans_data)
#  24%|██▍       | 246/1026 [03:02<09:08,  1.42it/s]/tmp/ipykernel_420/3009232229.py:7: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   km.fit(trans_data)
#  25%|██▍       | 253/1026 [03:07<09:11,  1.40it/s]/tmp/ipykernel_420/3009232229.py:7: ConvergenceWarning: Number of distinct clusters (18) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   km.fit(trans_data)
#  25%|██▍       | 254/1026 [03:08<08:52,  1.45it/s]/tmp/ipykernel_420/3009232229.py:7: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   km.fit(trans_data)
#  25%|██▍       | 255/1026 [03:09<08:59,  1.43it/s]/tmp/ipykernel_420/3009232229.py:7: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   km.fit(trans_data)
#  25%|██▍       | 256/1026 [03:09<08:49,  1.46it/s]/tmp/ipykernel_420/3009232229.py:7: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   km.fit(trans_data)
#  25%|██▌       | 260/1026 [03:12<09:29,  1.34it/s]/tmp/ipykernel_420/3009232229.py:7: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   km.fit(trans_data)
#  25%|██▌       | 261/1026 [03:13<09:39,  1.32it/s]/tmp/ipykernel_420/3009232229.py:7: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   km.fit(trans_data)
#  26%|██▌       | 265/1026 [03:16<08:48,  1.44it/s]/tmp/ipykernel_420/3009232229.py:7: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   km.fit(trans_data)
#  26%|██▌       | 269/1026 [03:19<08:49,  1.43it/s]/tmp/ipykernel_420/3009232229.py:7: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   km.fit(trans_data)
#  27%|██▋       | 276/1026 [03:24<08:44,  1.43it/s]/tmp/ipykernel_420/3009232229.py:7: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   km.fit(trans_data)
#  27%|██▋       | 281/1026 [03:27<08:49,  1.41it/s]/tmp/ipykernel_420/3009232229.py:7: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   km.fit(trans_data)
#  28%|██▊       | 286/1026 [03:31<09:03,  1.36it/s]/tmp/ipykernel_420/3009232229.py:7: ConvergenceWarning: Number of distinct clusters (18) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   km.fit(trans_data)
#  29%|██▊       | 293/1026 [03:36<08:46,  1.39it/s]/tmp/ipykernel_420/3009232229.py:7: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   km.fit(trans_data)
#  29%|██▊       | 294/1026 [03:37<08:43,  1.40it/s]/tmp/ipykernel_420/3009232229.py:7: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   km.fit(trans_data)
#  29%|██▉       | 296/1026 [03:38<08:50,  1.38it/s]/tmp/ipykernel_420/3009232229.py:7: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   km.fit(trans_data)
#  29%|██▉       | 297/1026 [03:39<08:46,  1.39it/s]/tmp/ipykernel_420/3009232229.py:7: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   km.fit(trans_data)
#  29%|██▉       | 301/1026 [03:42<08:37,  1.40it/s]/tmp/ipykernel_420/3009232229.py:7: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   km.fit(trans_data)
#  30%|██▉       | 303/1026 [03:43<08:37,  1.40it/s]/tmp/ipykernel_420/3009232229.py:7: ConvergenceWarning: Number of distinct clusters (18) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   km.fit(trans_data)
#  30%|██▉       | 305/1026 [03:45<08:37,  1.39it/s]/tmp/ipykernel_420/3009232229.py:7: ConvergenceWarning: Number of distinct clusters (18) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   km.fit(trans_data)
#  30%|██▉       | 306/1026 [03:45<08:45,  1.37it/s]/tmp/ipykernel_420/3009232229.py:7: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   km.fit(trans_data)
#  30%|██▉       | 307/1026 [03:46<08:25,  1.42it/s]/tmp/ipykernel_420/3009232229.py:7: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   km.fit(trans_data)
#  30%|███       | 308/1026 [03:47<08:23,  1.43it/s]/tmp/ipykernel_420/3009232229.py:7: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   km.fit(trans_data)
#  30%|███       | 309/1026 [03:47<08:18,  1.44it/s]/tmp/ipykernel_420/3009232229.py:7: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   km.fit(trans_data)
#  30%|███       | 311/1026 [03:49<08:27,  1.41it/s]/tmp/ipykernel_420/3009232229.py:7: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   km.fit(trans_data)
#  31%|███       | 313/1026 [03:50<08:37,  1.38it/s]/tmp/ipykernel_420/3009232229.py:7: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   km.fit(trans_data)
#  31%|███       | 315/1026 [03:52<08:42,  1.36it/s]/tmp/ipykernel_420/3009232229.py:7: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   km.fit(trans_data)
#  31%|███       | 318/1026 [03:54<08:23,  1.41it/s]/tmp/ipykernel_420/3009232229.py:7: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   km.fit(trans_data)
#  31%|███       | 319/1026 [03:54<08:04,  1.46it/s]/tmp/ipykernel_420/3009232229.py:7: ConvergenceWarning: Number of distinct clusters (18) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   km.fit(trans_data)
#  31%|███▏      | 321/1026 [03:56<08:17,  1.42it/s]/tmp/ipykernel_420/3009232229.py:7: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   km.fit(trans_data)
#  32%|███▏      | 325/1026 [03:59<08:27,  1.38it/s]/tmp/ipykernel_420/3009232229.py:7: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   km.fit(trans_data)
#  32%|███▏      | 329/1026 [04:02<08:11,  1.42it/s]/tmp/ipykernel_420/3009232229.py:7: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   km.fit(trans_data)
#  32%|███▏      | 331/1026 [04:03<08:22,  1.38it/s]/tmp/ipykernel_420/3009232229.py:7: ConvergenceWarning: Number of distinct clusters (18) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   km.fit(trans_data)
#  33%|███▎      | 334/1026 [04:05<08:32,  1.35it/s]/tmp/ipykernel_420/3009232229.py:7: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   km.fit(trans_data)
#  33%|███▎      | 335/1026 [04:06<08:29,  1.36it/s]/tmp/ipykernel_420/3009232229.py:7: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   km.fit(trans_data)
#  33%|███▎      | 339/1026 [04:09<08:18,  1.38it/s]/tmp/ipykernel_420/3009232229.py:7: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   km.fit(trans_data)
#  34%|███▎      | 345/1026 [04:14<08:39,  1.31it/s]/tmp/ipykernel_420/3009232229.py:7: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   km.fit(trans_data)
#  34%|███▍      | 347/1026 [04:16<10:00,  1.13it/s]/tmp/ipykernel_420/3009232229.py:7: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   km.fit(trans_data)
#  35%|███▍      | 355/1026 [04:22<08:50,  1.27it/s]/tmp/ipykernel_420/3009232229.py:7: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   km.fit(trans_data)
#  35%|███▍      | 358/1026 [04:25<10:17,  1.08it/s]/tmp/ipykernel_420/3009232229.py:7: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   km.fit(trans_data)
#  35%|███▌      | 361/1026 [04:28<10:00,  1.11it/s]/tmp/ipykernel_420/3009232229.py:7: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   km.fit(trans_data)
#  36%|███▌      | 365/1026 [04:31<08:28,  1.30it/s]/tmp/ipykernel_420/3009232229.py:7: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   km.fit(trans_data)
#  37%|███▋      | 376/1026 [04:40<07:42,  1.41it/s]/tmp/ipykernel_420/3009232229.py:7: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   km.fit(trans_data)
#  37%|███▋      | 377/1026 [04:40<08:00,  1.35it/s]/tmp/ipykernel_420/3009232229.py:7: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   km.fit(trans_data)
#  37%|███▋      | 379/1026 [04:42<08:21,  1.29it/s]/tmp/ipykernel_420/3009232229.py:7: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   km.fit(trans_data)
#  37%|███▋      | 382/1026 [04:44<07:54,  1.36it/s]/tmp/ipykernel_420/3009232229.py:7: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   km.fit(trans_data)
#  38%|███▊      | 386/1026 [04:47<07:51,  1.36it/s]/tmp/ipykernel_420/3009232229.py:7: ConvergenceWarning: Number of distinct clusters (18) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   km.fit(trans_data)
#  38%|███▊      | 387/1026 [04:48<08:03,  1.32it/s]/tmp/ipykernel_420/3009232229.py:7: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   km.fit(trans_data)
#  38%|███▊      | 394/1026 [04:53<08:03,  1.31it/s]/tmp/ipykernel_420/3009232229.py:7: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   km.fit(trans_data)
#  39%|███▉      | 401/1026 [04:58<07:25,  1.40it/s]/tmp/ipykernel_420/3009232229.py:7: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   km.fit(trans_data)
#  40%|████      | 414/1026 [05:07<07:34,  1.35it/s]/tmp/ipykernel_420/3009232229.py:7: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   km.fit(trans_data)
#  41%|████      | 416/1026 [05:09<07:26,  1.37it/s]/tmp/ipykernel_420/3009232229.py:7: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   km.fit(trans_data)
#  41%|████      | 419/1026 [05:11<07:28,  1.35it/s]/tmp/ipykernel_420/3009232229.py:7: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   km.fit(trans_data)
#  41%|████      | 422/1026 [05:13<07:33,  1.33it/s]/tmp/ipykernel_420/3009232229.py:7: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   km.fit(trans_data)
#  41%|████▏     | 424/1026 [05:15<07:26,  1.35it/s]/tmp/ipykernel_420/3009232229.py:7: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   km.fit(trans_data)
#  41%|████▏     | 425/1026 [05:15<07:10,  1.40it/s]/tmp/ipykernel_420/3009232229.py:7: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   km.fit(trans_data)
#  42%|████▏     | 432/1026 [05:21<07:39,  1.29it/s]/tmp/ipykernel_420/3009232229.py:7: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   km.fit(trans_data)
#  43%|████▎     | 440/1026 [05:26<07:01,  1.39it/s]/tmp/ipykernel_420/3009232229.py:7: ConvergenceWarning: Number of distinct clusters (18) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   km.fit(trans_data)
#  43%|████▎     | 444/1026 [05:29<06:41,  1.45it/s]/tmp/ipykernel_420/3009232229.py:7: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   km.fit(trans_data)
#  43%|████▎     | 445/1026 [05:30<06:42,  1.44it/s]/tmp/ipykernel_420/3009232229.py:7: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   km.fit(trans_data)
#  44%|████▎     | 448/1026 [05:32<06:50,  1.41it/s]/tmp/ipykernel_420/3009232229.py:7: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   km.fit(trans_data)
#  44%|████▍     | 449/1026 [05:33<06:59,  1.38it/s]/tmp/ipykernel_420/3009232229.py:7: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   km.fit(trans_data)
#  44%|████▍     | 453/1026 [05:36<06:46,  1.41it/s]/tmp/ipykernel_420/3009232229.py:7: ConvergenceWarning: Number of distinct clusters (18) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   km.fit(trans_data)
#  45%|████▍     | 461/1026 [05:42<06:51,  1.37it/s]/tmp/ipykernel_420/3009232229.py:7: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   km.fit(trans_data)
#  45%|████▌     | 463/1026 [05:43<06:38,  1.41it/s]/tmp/ipykernel_420/3009232229.py:7: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   km.fit(trans_data)
#  46%|████▌     | 467/1026 [05:46<06:47,  1.37it/s]/tmp/ipykernel_420/3009232229.py:7: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   km.fit(trans_data)
#  46%|████▌     | 472/1026 [05:50<06:42,  1.38it/s]/tmp/ipykernel_420/3009232229.py:7: ConvergenceWarning: Number of distinct clusters (18) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   km.fit(trans_data)
#  46%|████▌     | 473/1026 [05:50<06:38,  1.39it/s]/tmp/ipykernel_420/3009232229.py:7: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   km.fit(trans_data)
#  46%|████▋     | 476/1026 [05:53<06:44,  1.36it/s]/tmp/ipykernel_420/3009232229.py:7: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   km.fit(trans_data)
#  47%|████▋     | 481/1026 [05:56<06:33,  1.39it/s]/tmp/ipykernel_420/3009232229.py:7: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   km.fit(trans_data)
#  47%|████▋     | 483/1026 [05:58<06:47,  1.33it/s]/tmp/ipykernel_420/3009232229.py:7: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   km.fit(trans_data)
#  47%|████▋     | 486/1026 [06:00<06:39,  1.35it/s]/tmp/ipykernel_420/3009232229.py:7: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   km.fit(trans_data)
#  48%|████▊     | 497/1026 [06:08<06:25,  1.37it/s]/tmp/ipykernel_420/3009232229.py:7: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   km.fit(trans_data)
#  49%|████▊     | 498/1026 [06:09<06:21,  1.38it/s]/tmp/ipykernel_420/3009232229.py:7: ConvergenceWarning: Number of distinct clusters (18) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   km.fit(trans_data)
#  49%|████▉     | 503/1026 [06:13<06:24,  1.36it/s]/tmp/ipykernel_420/3009232229.py:7: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   km.fit(trans_data)
#  50%|████▉     | 510/1026 [06:17<05:59,  1.44it/s]/tmp/ipykernel_420/3009232229.py:7: ConvergenceWarning: Number of distinct clusters (18) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   km.fit(trans_data)
#  65%|██████▍   | 662/1026 [08:11<04:14,  1.43it/s]/tmp/ipykernel_420/3009232229.py:7: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   km.fit(trans_data)
# 100%|██████████| 1026/1026 [12:42<00:00,  1.35it/s]
